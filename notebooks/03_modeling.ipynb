# %%
import pandas as pd

df = pd.read_parquet("../data/processed_data.parquet")
print(df.head(10))
print((df['casual'] + df['registered'] == df['cnt']).all())
# Out:
#                datetime  season  yr  mnth  hr  holiday  weekday  workingday  \
# 237 2011-01-11 06:00:00       1   0     1   6        0        2           1
# 238 2011-01-11 07:00:00       1   0     1   7        0        2           1
# 239 2011-01-11 08:00:00       1   0     1   8        0        2           1
# 240 2011-01-11 09:00:00       1   0     1   9        0        2           1
# 241 2011-01-11 10:00:00       1   0     1  10        0        2           1
# 242 2011-01-11 11:00:00       1   0     1  11        0        2           1
# 243 2011-01-11 12:00:00       1   0     1  12        0        2           1
# 244 2011-01-11 13:00:00       1   0     1  13        0        2           1
# 245 2011-01-11 14:00:00       1   0     1  14        0        2           1
# 246 2011-01-11 15:00:00       1   0     1  15        0        2           1
#
#      weathersit  temp  ...   hum  windspeed  casual  registered  cnt  lag_1h  \
# ...

# %%
features = ["season", "yr", "mnth", "hr", "holiday", "weekday", "workingday", "weathersit", "temp", "atemp", "hum", "windspeed","lag_1h", "lag_24h", "lag_168h", "rolling_mean_3h", "rolling_mean_24h"]
X = df[features]
Y = df["cnt"]
print(X.shape, Y.shape)

train = df[df["yr"]==0]
test = df[df["yr"]==1]
X_train = train[features]
Y_train = train["cnt"]
X_test = test[features]
Y_test = test["cnt"]
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)

print("Train:", len(train) / len(df) * 100, "%")
print("Test:", len(test) / len(df) * 100, "%")
# Out:
# (17142, 17) (17142,)
# (8408, 17) (8408,)
# (8734, 17) (8734,)
# Train: 49.0491191226228 %
# Test: 50.9508808773772 %

# %%
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np

model = GradientBoostingRegressor(n_estimators=100, random_state=42)
tscv = TimeSeriesSplit(n_splits=5)
cross
